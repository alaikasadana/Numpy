# %%
import numpy as np

# %%
arr=np.array([1,2,34,4,56,6,70,8,90,18,14,16,])
# np.reshape(arr,(3,4))
arr.reshape((4,-1))
arr.reshape((-1,4))
# Out:
# array([[ 1,  2, 34,  4],
#        [56,  6, 70,  8],
#        [90, 18, 14, 16]])

# %%
a = np.array([12,2,4,5])
b = np.array([5,7,92,0])

np.concatenate((a,b))
# Out:
# array([12,  2,  4,  5,  5,  7, 92,  0])

# %%
a = np.array([[12,2,4,5],[2,3,6,8]])
b = np.array([[5,7,92,0],[6,99,29,19]])

np.concatenate((a,b),axis=1)
# Out:
# array([[12,  2,  4,  5,  5,  7, 92,  0],
#        [ 2,  3,  6,  8,  6, 99, 29, 19]])

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[12,  2,  4,  5],
#        [ 2,  3,  6,  8],
#        [ 5,  7, 92,  0],
#        [ 6, 99, 29, 19]])

# %%
np.concatenate((a,b),axis=None)
# Out:
# array([12,  2,  4,  5,  2,  3,  6,  8,  5,  7, 92,  0,  6, 99, 29, 19])

# %%
np.unique(a)
# Out:
# array([ 2,  3,  4,  5,  6,  8, 12])

# %%
np.count_nonzero(b)
# Out:
# np.int64(7)

# %%
size = np.size(b)
count = np.count_nonzero(b)
print(size-count)
# Out:
# 1

# %%
np.unique(b).size
# Out:
# 8

# %%
np.unique_counts(b)
# Out:
# UniqueCountsResult(values=array([ 0,  5,  6,  7, 19, 29, 92, 99]), counts=array([1, 1, 1, 1, 1, 1, 1, 1]))

# %%
arr = np.array([0,0,0,6,72,8,0,8,801,0,0,0,0])
np.trim_zeros(arr)
# Out:
# array([  6,  72,   8,   0,   8, 801])

# %%
np.trim_zeros(arr,trim='fb')
# Out:
# array([  6,  72,   8,   0,   8, 801])

# %%
np.trim_zeros(arr,trim='f')
# Out:
# array([  6,  72,   8,   0,   8, 801,   0,   0,   0,   0])

# %%
np.trim_zeros(arr,trim='b')
# Out:
# array([  0,   0,   0,   6,  72,   8,   0,   8, 801])

# %%
a = np.copy(arr)

# %%
b = arr.view()

# %%
import numpy as np

# Original array
arr = np.array([10, 20, 30, 40, 50])

# Create a view
b = arr.view()

print("Original array:", arr)
print("View array:", b)

# Modify the view
b[2] = 99

print("\nAfter modifying the view:")
print("Original array:", arr)
print("View array:", b)
# Out:
# Original array: [10 20 30 40 50]
# View array: [10 20 30 40 50]
#
# After modifying the view:
# Original array: [10 20 99 40 50]
# View array: [10 20 99 40 50]

# %%
import numpy as np

# Original array
arr = np.array([10, 20, 30, 40, 50])

# Create a copy
c = arr.copy()

print("Original array:", arr)
print("Copied array:", c)

# Modify the copy
c[2] = 99

print("\nAfter modifying the copy:")
print("Original array:", arr)
print("Copied array:", c)
# Out:
# Original array: [10 20 30 40 50]
# Copied array: [10 20 30 40 50]
#
# After modifying the copy:
# Original array: [10 20 30 40 50]
# Copied array: [10 20 99 40 50]

# %%
a = np.array([1,2,3,4,5,6])
b = np.array([4,5,6,7,8,9])

np.setxor1d(a,b)
# Out:
# array([1, 2, 3, 7, 8, 9])

# %%
a = np.array([1,2,3,4,5,6])
b = np.array([4,5,6,7,8,9])

np.setdiff1d(a,b)
# Out:
# array([1, 2, 3])

# %%
a = np.array([1,2,3,4,5,6])
b = np.array([4,5,6,7,8,9])

np.setdiff1d(b,a)
# Out:
# array([7, 8, 9])

# %% [markdown]
# Multiplication

# %%
np.dot(a,b)
# Out:
# np.int64(154)

# %%
a = np.array([[12,2],[2,3]])
b = np.array([[5,7],[6,99]])

# %%
np.dot(a,b)
# Out:
# array([[ 72, 282],
#        [ 28, 311]])

# %%
a = np.array([[[12,2,8],[2,3,4],[9,8,9]]])
b = np.array([[[5,7,4],[6,99,3],[10,23,2]]])
np.cross(a,b)
# Out:
# array([[[ -48,   -8,   74],
#         [-387,   18,  180],
#         [-191,   72,  127]]])

# %%
a= np.array([1,2,3])
b = np.array([4,5,6])
np.cross(a,b)
# Out:
# array([-3,  6, -3])

# %%
arr1 = np.array([[1,2,3],[4,5,6]])
arr2 = np.array([[4,5,6],[7,8,9]])
np.cross(arr1,arr2)
# Out:
# array([[-3,  6, -3],
#        [-3,  6, -3]])

# %%
print(a @ b)
# Out:
# 32
