# %%
import numpy as np

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(data[0]+data[1])
# Out:
# [30 50 70 60]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(data[0]*data[1])
# Out:
# [ 200  600 1200  800]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(data[0]-data[1])
# Out:
# [-10 -10 -10  20]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(20+data)
# Out:
# [[30 40 50 60]
#  [40 50 60 40]]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(np.square(data))
# Out:
# [[ 100  400  900 1600]
#  [ 400  900 1600  400]]

# %%
print(np.sqrt(data))
# Out:
# [[3.16227766 4.47213595 5.47722558 6.32455532]
#  [4.47213595 5.47722558 6.32455532 4.47213595]]
