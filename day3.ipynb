# %%
import matplotlib.pyplot as mp

data = [1,2,4,7,8]
second = [10,30,50,70,90]

mp.plot(data,second)

# %%
import matplotlib.pyplot as mp
import numpy as np 
a = np.arange(1,10)
b = np.arange(11,20)

mp.plot(a,b)
